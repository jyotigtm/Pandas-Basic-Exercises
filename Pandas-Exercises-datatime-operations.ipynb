# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset [wind.csv](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data) from the folder

# %%
pd.read_csv('wind.data')
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# 5     61   1   6  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42
# 6     61   1   7  13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29
# 7     61   1   8  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62
# 8     61   1   9  12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13
# 9     61   1  10  13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79
# 10    61   1  11  10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33
# 11    61   1  12  19.75  12.08  18.50  10.54  10.29   9.46  15.54  11.50
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('wind.data')
data.head(2)
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS   KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17  9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83  6.50  12.62  7.67  11.50  10.04   9.79
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83

# %%
pd.to_datetime(data.Yr*10000+data.Mo*100+data.Dy, format = '%y%m%d')
data['Date'] = pd.to_datetime(data.Yr*10000+data.Mo*100+data.Dy, format = '%y%m%d')
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL       Date
# 0  12.58  18.50  15.04 2061-01-01
# 1   9.67  17.54  13.83 2061-01-02
# 2   7.67  12.75  12.71 2061-01-03
# 3   5.88   5.46  10.88 2061-01-04
# 4  10.34  12.92  11.83 2061-01-05

# %%
data.drop(['Yr','Mo','Dy'], axis=1, inplace=True)

# %%
data.head(2)
# Out:
#      RPT    VAL    ROS   KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17  9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83  6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02

# %% [markdown]
# ### Step 4. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
import numpy as np 

now = pd.Timestamp('now')
data['Date'] = data['Date'].where(data['Date'] < now, data['Date'] -  np.timedelta64(100, 'Y'))

# %%
data['Date'].head()
# Out:
# 0   1961-01-01 18:00:00
# 1   1961-01-02 18:00:00
# 2   1961-01-03 18:00:00
# 3   1961-01-04 18:00:00
# 4   1961-01-05 18:00:00
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index(data.Date, inplace=True)
data.head()
# Out:
#                        RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# Date
# 1961-01-01 18:00:00  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 1961-01-02 18:00:00  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 1961-01-03 18:00:00  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 1961-01-04 18:00:00  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 1961-01-05 18:00:00  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
#                        MUL    CLO    BEL    MAL                Date
# Date
# 1961-01-01 18:00:00  10.83  12.58  18.50  15.04 1961-01-01 18:00:00
# 1961-01-02 18:00:00   9.79   9.67  17.54  13.83 1961-01-02 18:00:00
# 1961-01-03 18:00:00   8.50   7.67  12.75  12.71 1961-01-03 18:00:00
# 1961-01-04 18:00:00   5.83   5.88   5.46  10.88 1961-01-04 18:00:00
# 1961-01-05 18:00:00  10.92  10.34  12.92  11.83 1961-01-05 18:00:00

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# RPT     6
# VAL     3
# ROS     2
# KIL     5
# SHA     2
# BIR     0
# DUB     3
# CLA     2
# MUL     3
# CLO     1
# BEL     0
# MAL     4
# Date    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.isnull().any().count()
# Out:
# 13

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stas = data.describe().T

# %%
loc_stats = loc_stas[['min', 'max', 'mean', 'std']]
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = data.resample('D').sum()
day_stats.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29   0.00  9.87  13.67  10.25  10.83
# 1961-01-02  14.71   0.00  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25   0.00   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
day_stats.agg({'mean', 'max', 'min', 'std'}).T
# Out:
#           mean    max   min       std
# RPT  12.351704  35.80  0.00  5.628245
# VAL  10.639457  33.37  0.00  5.271060
# ROS  11.656979  33.84  0.00  5.011816
# KIL   6.301672  28.46  0.00  3.608631
# SHA  10.452653  37.54  0.00  4.938742
# BIR   7.092254  26.16  0.00  3.968683
# DUB   9.792872  30.37  0.00  4.980816
# CLA   8.492469  31.08  0.00  4.501204
# MUL   8.489714  25.88  0.00  4.169870
# CLO   8.706007  28.21  0.00  4.504892
# BEL  13.121007  42.38  0.13  5.835037
# MAL  15.589588  42.54  0.00  6.708793

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
january_data = data[data.index.month == 1]
print ('January windspeeds:',january_data.mean())
# Out:
# January windspeeds: RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
'Yearly:', data.resample('A').mean()
# Out:
# ('Yearly:',
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
#  Date
#  1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
#  1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
#  1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
#  1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
#  1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
#  1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
#  1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
#  1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
#  1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
#  1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
#  1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
'Monthly:', data.resample('M').mean()
# Out:
# ('Monthly:',
#                    RPT        VAL        ROS       KIL        SHA        BIR  \
#  Date
#  1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
#  1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
#  1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
#  1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
#  1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
#  1961-06-30   9.904138   8.520333   8.867000  6.083000  10.824000   6.707333
#  1961-07-31  10.614194   8.221613   9.110323  6.340968  10.532581   6.198387
#  1961-08-31  12.035000  10.133871  10.335806  6.845806  12.715161   8.441935
#  1961-09-30  12.531000   9.656897  10.776897  7.155517  11.003333   7.234000
#  1961-10-31  14.289667  10.915806  12.236452  8.154839  11.865484   8.333871
#  1961-11-30  10.896333   8.592667  11.850333  6.045667   9.123667   6.250667
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
'Weekly:', data.resample('W').mean()
# Out:
# ('Weekly:',
#                    RPT        VAL        ROS        KIL        SHA        BIR  \
#  Date
#  1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
#  1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
#  1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
#  1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
#  1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
#  1961-02-05  16.827143  15.460000  12.618571   8.247143  13.361429   9.107143
#  1961-02-12  19.684286  16.417143  17.304286  10.774286  14.718571  12.522857
#  1961-02-19  15.130000  15.091429  13.797143  10.083333  13.410000  11.868571
#  1961-02-26  15.221429  13.625714  14.334286   8.524286  13.655714  10.114286
#  1961-03-05  12.101429  12.951429  11.063333   7.834286  12.101429   9.238571
#  1961-03-12   9.376667  11.578571  10.845714   7.137143  10.940000   9.488571
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
monthwisedata = data.resample('M').mean()
monthwisedata.head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
#
#                   DUB        CLA        MUL        CLO        BEL        MAL
# Date
# 1961-01-31  11.184839   9.245333   9.085806  10.107419  13.880968  14.703226
# 1961-02-28  11.890714  11.846071  11.821429  12.714286  18.583214  15.411786
# 1961-03-31   9.644194   9.829677  10.294138  11.251935  16.410968  15.720000
# 1961-04-30   6.925333   7.094667   7.342333   7.237000  11.147333  10.278333
# 1961-05-31   7.604000   8.177097   8.039355   8.499355  11.900323  12.011613

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data1 = data[data.index.year == 1961]
stats = data1.resample('W', how='mean').apply(lambda x: x.describe())
stats.T
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#      count       mean       std       min        25%        50%        75%  \
# RPT   53.0  12.341033  3.390879  4.202857  10.236667  11.715714  15.130000
# VAL   53.0  10.419380  2.874840  4.255714   8.445714   9.734286  12.951429
# ROS   53.0  11.381716  2.830804  6.738571   9.104286  10.875714  13.170000
# KIL   53.0   6.990952  2.072540  3.300000   5.478571   6.578571   8.370000
# SHA   52.0  10.876502  2.677186  6.112857   8.966071  10.357143  13.277857
# BIR   53.0   7.764340  2.426115  2.715714   6.017143   7.492857   9.238571
# DUB   53.0   9.805135  2.837580  3.964286   7.642857   9.542857  11.888333
# CLA   53.0   8.869915  2.440596  4.257143   6.884286   8.977143  10.250000
# MUL   53.0   8.694681  2.404598  4.501429   6.748571   8.714286  10.392857
# ...
